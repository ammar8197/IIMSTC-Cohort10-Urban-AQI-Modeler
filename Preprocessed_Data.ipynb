# %% [markdown]
# <a href="https://colab.research.google.com/github/PRIYAGUNAR/IIMSTC-Cohort10-Urban-AQI-Modeler/blob/main/Preprocessed_Data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
numerical_cols = ['PM2.5','PM10','TEMP','PRES','DEWP','RAIN','WSPM']

for col in numerical_cols:

    Q1 = df[col].quantile(0.25)
    Q3 = df[col].quantile(0.75)

    IQR = Q3 - Q1

    lower = Q1 - 1.5 * IQR
    upper = Q3 + 1.5 * IQR

    df = df[(df[col] >= lower) & (df[col] <= upper)]

# %%
features = ['TEMP','PRES','DEWP','RAIN','wd','WSPM','Hour']
X = df[features]

y = df['PM2.5']
scaler = StandardScaler()

X_scaled = scaler.fit_transform(X)

# Convert scaled data to DataFrame
X_scaled = pd.DataFrame(X_scaled, columns=features)

# %%
from google.colab import files

files.download("final_air_quality_dataset.csv")
